# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
titanic[['Age','Fare']].describe().round(2)
# Out:
#           Age    Fare
# count  714.00  891.00
# mean    29.70   32.20
# std     14.53   49.69
# min      0.42    0.00
# 25%     20.12    7.91
# 50%     28.00   14.45
# 75%     38.00   31.00
# max     80.00  512.33

# %%
titanic['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
titanic['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic.duplicated().sum()
# Out:
# 0

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic['Age'].head(20)
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5      NaN
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17     NaN
# 18    31.0
# 19     NaN
# Name: Age, dtype: float64

# %%
titanic.drop(["Cabin"], axis = 1, inplace = True)
titanic
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Embarked
# 0           A/5 21171   7.2500        S
# 1            PC 17599  71.2833        C
# 2    STON/O2. 3101282   7.9250        S
# 3              113803  53.1000        S
# ...

# %%
titanic.dropna(subset='Embarked',inplace=True)
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Sex          889 non-null    object
#  4   Age          712 non-null    float64
#  5   SibSp        889 non-null    int64
#  6   Parch        889 non-null    int64
#  7   Ticket       889 non-null    object
#  8   Fare         889 non-null    float64
#  9   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 76.4+ KB

# %%
titanic['Parch'].value_counts()
# Out:
# 0    676
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
titanic['SibSp'].value_counts()
# Out:
# 0    606
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
plt.boxplot(titanic['Age'])
plt.show()

# %%
plt.boxplot(titanic['Fare'])
plt.show()

# %%
titanic[titanic['Fare']>300]
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch    Ticket  \
# 258          259         1       1  female  35.0      0      0  PC 17755
# 679          680         1       1    male  36.0      0      1  PC 17755
# 737          738         1       1    male  35.0      0      0  PC 17755
#
#          Fare Embarked
# 258  512.3292        C
# 679  512.3292        C
# 737  512.3292        C

# %%
sns.violinplot(data = titanic , x='Fare')
# Out:
# <Axes: xlabel='Fare'>

# %%
sns.violinplot(data = titanic , x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
titanic[['Age','Fare']].describe().round(2)
# Out:
#           Age    Fare
# count  712.00  889.00
# mean    29.64   32.10
# std     14.49   49.70
# min      0.42    0.00
# 25%     20.00    7.90
# 50%     28.00   14.45
# 75%     38.00   31.00
# max     80.00  512.33

# %%
q1fare = 7.90
q3fare = 31.00
iqrfare = q3fare - q1fare
minoutliresfare = q1fare-1.5*iqrfare
maxoutliresfare = q3fare+1.5*iqrfare

# %%
minoutliresfare
# Out:
# -26.750000000000007

# %%
maxoutliresfare
# Out:
# 65.65

# %%
q1age = 20.12
q3age = 38.00
iqrage = q3age - q1age
minoutliresage = q1age-1.5*iqrage
maxoutliresage = q3age+1.5*iqrage

# %%
minoutliresage
# Out:
# -6.699999999999999

# %%
maxoutliresage
# Out:
# 64.82

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Embarked
# 0           A/5 21171   7.2500        S
# 1            PC 17599  71.2833        C
# 2    STON/O2. 3101282   7.9250        S
# 3              113803  53.1000        S
# ...

# %%
titanic.drop(titanic[(titanic['Fare'] > 65.65)].index, inplace=True)
titanic.head(10)
# Out:
#     PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0             1         0       3    male  22.0      1      0
# 2             3         1       3  female  26.0      0      0
# 3             4         1       1  female  35.0      1      0
# 4             5         0       3    male  35.0      0      0
# 5             6         0       3    male   NaN      0      0
# 6             7         0       1    male  54.0      0      0
# 7             8         0       3    male   2.0      3      1
# 8             9         1       3  female  27.0      0      2
# 9            10         1       2  female  14.0      1      0
# 10           11         1       3  female   4.0      1      1
#
#               Ticket     Fare Embarked
# 0          A/5 21171   7.2500        S
# 2   STON/O2. 3101282   7.9250        S
# 3             113803  53.1000        S
# 4             373450   8.0500        S
# 5             330877   8.4583        Q
# 6              17463  51.8625        S
# ...

# %%
titanic.drop(titanic[(titanic['Age'] > 64.82)].index, inplace=True)
titanic
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# 5              6         0       3    male   NaN      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Embarked
# 0           A/5 21171   7.2500        S
# 2    STON/O2. 3101282   7.9250        S
# 3              113803  53.1000        S
# 4              373450   8.0500        S
# ...

# %%
round(titanic['Age'].mean(skipna=True),2)
# Out:
# 28.27

# %%
titanic['Age'].fillna(28.27,inplace=True)
titanic
# Out:
#      PassengerId  Survived  Pclass     Sex    Age  SibSp  Parch  \
# 0              1         0       3    male  22.00      1      0
# 2              3         1       3  female  26.00      0      0
# 3              4         1       1  female  35.00      1      0
# 4              5         0       3    male  35.00      0      0
# 5              6         0       3    male  28.27      0      0
# ..           ...       ...     ...     ...    ...    ...    ...
# 886          887         0       2    male  27.00      0      0
# 887          888         1       1  female  19.00      0      0
# 888          889         0       3  female  28.27      1      2
# 889          890         1       1    male  26.00      0      0
# 890          891         0       3    male  32.00      0      0
#
#                Ticket     Fare Embarked
# 0           A/5 21171   7.2500        S
# 2    STON/O2. 3101282   7.9250        S
# 3              113803  53.1000        S
# ...

# %%
sns.violinplot(data = titanic , x='Fare')
# Out:
# <Axes: xlabel='Fare'>

# %%
sns.violinplot(data = titanic , x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 765 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  765 non-null    int64
#  1   Survived     765 non-null    int64
#  2   Pclass       765 non-null    int64
#  3   Sex          765 non-null    object
#  4   Age          765 non-null    float64
#  5   SibSp        765 non-null    int64
#  6   Parch        765 non-null    int64
#  7   Ticket       765 non-null    object
#  8   Fare         765 non-null    float64
#  9   Embarked     765 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 65.7+ KB

# %%
titanic.to_csv('titanic-modified.csv')
